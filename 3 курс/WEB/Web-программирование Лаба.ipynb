# %% [markdown]
# ## 1. Чтение и запись файлов
#
# ## Задание: Напишите программу, которая открывает текстовый файл input.txt, считывает его содержимое, удаляет все пустые строки и записывает результат в новый файл output.txt.

# %% [markdown]
# ## 2. Работа со списками
#
# ## Задание: Напишите функцию, которая принимает на вход список чисел и возвращает новый список, содержащий только те числа, которые больше среднего значения всех чисел исходного списка.

# %% [markdown]
# ## 3. Словари и работа с данными
#
# ## Задание: Создайте словарь с информацией о студентах (ключи — фамилии студентов, значения — их оценки). Напишите программу, которая находит студента с самой высокой оценкой и выводит его имя.

# %% [markdown]
# ## 4. Работа с функциями
#
# ## Задание: Реализуйте функцию, которая принимает строку и возвращает количество гласных и согласных букв в строке. Игнорируйте пробелы и знаки препинания.

# %% [markdown]
# ## 5. Циклы и условия
#
# ## Задание: Напишите программу, которая запрашивает у пользователя целое число и выводит все простые числа меньше этого числа.

# %% [markdown]
# ## 6. Классы и объекты
#
# ## Задание: Создайте класс Книга, который будет содержать информацию о названии книги, авторе и количестве страниц. Реализуйте метод для вывода информации о книге и метод для изменения количества страниц.

# %%
class Book():
    def __init__(self , title , author , pages):
        self.title = 

    def info():

    def update_pages():

# %% [markdown]
# ## 7. Модули и библиотеки
#
# ## Задание: Используя модуль random, напишите программу, которая генерирует случайный пароль длиной 8 символов. Пароль должен содержать буквы и цифры.

# %%
import random
import string

def generate_password(lenght = 8) :
